# %% [markdown]
# # 1. Readnig csv files

# %% [markdown]
# Our data come from the Seattle Open Data website (https://data.seattle.gov/). Unfortunately, they have no united structure. That's why we have to pre-process each year separately. Also, our source page is missing 2018 data, so we have a gap there.
# Problems we found out:
# - different data types in one column (e.g flota, int)
# - missing key data
# - some unnecessary columns (e.g comments)
# - incomprehensible way of calculating surface (there are columns that contain 1st, 2nd, 3rd property surface, but often their sum is not equal to the overall surface)
# - different columns names
# - mixed up columns order
#
# Functions below are made to process each year separately and exclude all discrepancies

# %%
import pandas as pd
import ast

def convert_columns(df, columns, new_type):
    for column in columns:
        df[column] = df[column].astype(new_type)
        

def drop_columns(df, columns_to_drop):
    df.drop(columns_to_drop, axis=1, inplace=True)
    
    # delete Nan and zeros 
    to_zero = df.loc[:, 'SiteEUI(kBtu/sf)':'NaturalGas(kBtu)'].columns.tolist()
    df[to_zero] = df[to_zero].fillna(0)
    df = df[df['SiteEnergyUse(kBtu)'] != 0]
    return df

def convert(df, convert_to_float, convert_to_int):
    convert_columns(df=df, columns=convert_to_float, new_type=float)
    convert_columns(df=df, columns=convert_to_int, new_type=int)
    return df

def rename(df, columns_to_rename):
    df.rename(columns=columns_to_rename, inplace=True)
    return df

def sort_columns(df, columns_order):
    df = df[columns_order]
    return df

fixed_columns_order =[
    'OSEBuildingID',
    'DataYear',
    'BuildingType',
    'PrimaryPropertyType',
    'PropertyName',
    'Address',
    'ZipCode',
    'CouncilDistrictCode',
    'Neighborhood',
    'Latitude',
    'Longitude',
    'YearBuilt',
    'NumberofFloors',
    'NumberofBuildings',
    'PropertyGFATotal',
    'PropertyGFAParking',
    'YearsENERGYSTARCertified',
    'ENERGYSTARScore',
    'SiteEUI(kBtu/sf)',
    'SiteEUIWN(kBtu/sf)',
    'SourceEUI(kBtu/sf)',
    'SourceEUIWN(kBtu/sf)',
    'SiteEnergyUse(kBtu)',
    'SiteEnergyUseWN(kBtu)',
    'SteamUse(kBtu)',
    'Electricity(kBtu)',
    'Electricity(kWh)',
    'NaturalGas(therms)',
    'NaturalGas(kBtu)',
    'GHGEmissions(MetricTonsCO2e)',
    'GHGEmissionsIntensity(kgCO2e/ft2)'
]

# %% [markdown]
# ## 2015

# %% [markdown]
# ### Extarcting address data
# We need to extract latitude, longitude, address and zip from this dict-like column

# %%
path_15 = 'data/raw/2015_Building_Energy_Benchmarking.csv'
sea_2015 = pd.read_csv(path_15)

print(sea_2015['Location'][0])
# Out:
# {'latitude': '47.61219025', 'longitude': '-122.33799744', 'human_address': '{"address": "405 OLIVE WAY", "city": "SEATTLE", "state": "WA", "zip": "98101"}'}

# %%
# creating dictionary from a string in "Location" column
sea_2015['Location'] = sea_2015['Location'].apply(ast.literal_eval)
sea_2015['Location'][0]
# Out:
# {'latitude': '47.61219025',
#  'longitude': '-122.33799744',
#  'human_address': '{"address": "405 OLIVE WAY", "city": "SEATTLE", "state": "WA", "zip": "98101"}'}

# %%
# creating 'latitude' and 'longitude' columns from the dictionary
location = pd.json_normalize(sea_2015['Location'])
location.head()
# Out:
#       latitude      longitude  \
# 0  47.61219025  -122.33799744
# 1  47.61310583  -122.33335756
# 2  47.61334897  -122.33769944
# 3  47.61421585  -122.33660889
# 4   47.6137544   -122.3409238
#
#                                        human_address
# 0  {"address": "405 OLIVE WAY", "city": "SEATTLE"...
# 1  {"address": "724 PINE ST", "city": "SEATTLE", ...
# 2  {"address": "1900 5TH AVE", "city": "SEATTLE",...
# 3  {"address": "620 STEWART ST", "city": "SEATTLE...
# 4  {"address": "401 LENORA ST", "city": "SEATTLE"...

# %%
# do the same operations for "Human_address" column
location['human_address'] = location['human_address'].apply(ast.literal_eval)
address = pd.json_normalize(location['human_address'])
address.head()
# Out:
#           address     city state    zip
# 0   405 OLIVE WAY  SEATTLE    WA  98101
# 1     724 PINE ST  SEATTLE    WA  98101
# 2    1900 5TH AVE  SEATTLE    WA  98101
# 3  620 STEWART ST  SEATTLE    WA  98101
# 4   401 LENORA ST  SEATTLE    WA  98121

# %%
# inserting new columns in a fixed order
sea_2015.insert(loc=5, column='Address', value=address['address'])
sea_2015.insert(loc=6, column='ZipCode', value=address['zip'])
sea_2015.insert(loc=9, column='Latitude', value=location['latitude'])
sea_2015.insert(loc=10, column='Longitude', value=location['longitude'])

columns_to_drop_15 =  [
    'TaxParcelIdentificationNumber',
    'Location',
    'PropertyGFABuilding(s)',
    'ListOfAllPropertyUseTypes',
    'LargestPropertyUseType', 
    'LargestPropertyUseTypeGFA', 
    'SecondLargestPropertyUseType',
    'SecondLargestPropertyUseTypeGFA', 
    'ThirdLargestPropertyUseType',
    'ThirdLargestPropertyUseTypeGFA', 
    'OtherFuelUse(kBtu)',
    'DefaultData',
    'Comment',
    'ComplianceStatus',
    'Outlier',
    '2010 Census Tracts',
    'Seattle Police Department Micro Community Policing Plan Areas',
    'City Council Districts',
    'SPD Beats',
    'Zip Codes'    
]

convert_to_float_15 = [
    'Latitude', 
    'Longitude',
    'ZipCode'
]

convert_to_int_15 = [
    'SiteEnergyUse(kBtu)',
    'SiteEnergyUseWN(kBtu)',
    'SteamUse(kBtu)',
    'Electricity(kBtu)',
    'Electricity(kWh)',
    'NaturalGas(kBtu)',
    'NaturalGas(therms)'
]

sea_2015 = drop_columns(sea_2015, columns_to_drop_15)
sea_2015 = convert(sea_2015, convert_to_float_15, convert_to_int_15)
sea_2015 = sort_columns(sea_2015, columns_order)

sea_2015.to_csv('data/clean/2015-building-energy-benchmarking-clean.csv', index=False)

# %% [markdown]
# ## 2016

# %%
path_16 = 'data/raw/2016_Building_Energy_Benchmarking.csv'

columns_to_drop_16 = [
    'City', 
    'State', 
    'TaxParcelIdentificationNumber',
    'PropertyGFABuilding(s)', 
    'ListOfAllPropertyUseTypes',
    'LargestPropertyUseType', 
    'LargestPropertyUseTypeGFA', 
    'SecondLargestPropertyUseType',
    'SecondLargestPropertyUseTypeGFA', 
    'ThirdLargestPropertyUseType',
    'ThirdLargestPropertyUseTypeGFA', 
    'DefaultData',
    'Comments',
    'Outlier',
    'ComplianceStatus'
]

convert_to_float_16 = [
    'Latitude', 
    'Longitude',
    'ZipCode'
]

convert_to_int_16 = [
    'SiteEnergyUse(kBtu)',
    'SiteEnergyUseWN(kBtu)',
    'Electricity(kBtu)',
    'NaturalGas(kBtu)'
]

columns_to_rename_16 = {
    'TotalGHGEmissions': 'GHGEmissions(MetricTonsCO2e)',
    'GHGEmissionsIntensity': 'GHGEmissionsIntensity(kgCO2e/ft2)'
}

sea_2016 = pd.read_csv(path_16)
sea_2016 = drop_columns(sea_2016, columns_to_drop_16)
sea_2016 = convert(sea_2016, convert_to_float_16, convert_to_int_16)
sea_2016 = rename(sea_2016, columns_to_rename_16)
sea_2016 = sort_columns(sea_2016, columns_order)

sea_2016.to_csv('data/clean/2016-building-energy-benchmarking-clean.csv', index=False)

# %% [markdown]
# ## 2017

# %%
sea_2017 = pd.read_csv('2017_Building_Energy_Benchmarking.csv')

path_17 = 'data/raw/2017_Building_Energy_Benchmarking.csv'

columns_to_drop_17 = [
    City', 
    'State', 
    'TaxParcelIdentificationNumber',
    'PropertyGFABuilding(s)', 
    'ListOfAllPropertyUseTypes',
    'LargestPropertyUseType', 
    'LargestPropertyUseTypeGFA', 
    'SecondLargestPropertyUseType',
    'SecondLargestPropertyUseTypeGFA', 
    'ThirdLargestPropertyUseType',
    'ThirdLargestPropertyUseTypeGFA', 
    'DefaultData',
    'Outlier',
    'ComplianceStatus'
]

convert_to_float_17 = [
    'Latitude', 
    'Longitude',
    'ZipCode'
]

convert_to_int_17 = [
    'SiteEnergyUse(kBtu)',
    'SiteEnergyUseWN(kBtu)',
    'Electricity(kBtu)',
    'NaturalGas(kBtu)'
]

columns_to_rename_17 = {
    'TotalGHGEmissions': 'GHGEmissions(MetricTonsCO2e)',
    'GHGEmissionsIntensity': 'GHGEmissionsIntensity(kgCO2e/ft2)'
}

sea_2017 = pd.read_csv(path_17)
sea_2017 = drop_columns(sea_2017, columns_to_drop_17)
sea_2017 = convert(sea_2017, convert_to_float_16, convert_to_int_17)
sea_2017 = rename(sea_2017, columns_to_rename_17)
sea_2017 = sort_columns(sea_2017, columns_order)

sea_2017.to_csv('data/clean/2017-building-energy-benchmarking-clean.csv', index=False)

# %% [markdown]
# # 2019

# %%
path_19 = 'data/raw/2019_Building_Energy_Benchmarking.csv'

columns_to_drop_19 = [
    'TaxParcelIdentificationNumber',
    'City', 
    'State', 
    'PropertyGFABuilding(s)', 
    'LargestPropertyUseType', 
    'LargestPropertyUseTypeGFA', 
    'SecondLargestPropertyUseType',
    'SecondLargestPropertyUseTypeGFA', 
    'ThirdLargestPropertyUseType',
    'ThirdLargestPropertyUseTypeGFA', 
    'EPAPropertyType',
    'ComplianceIssue',
    'ComplianceStatus'
]

convert_to_float_19 = [
    'Latitude', 
    'Longitude',
    'ZipCode'
]

convert_to_int_19 = [
    'SiteEnergyUse(kBtu)',
    'SiteEnergyUseWN(kBtu)',
    'Electricity(kBtu)',
    'NaturalGas(kBtu)'
]

columns_to_rename_19 = {
    'BuildingName': 'PropertyName',
    'TotalGHGEmissions': 'GHGEmissions(MetricTonsCO2e)',
    'GHGEmissionsIntensity': 'GHGEmissionsIntensity(kgCO2e/ft2)'
}

columns_to_add_19 = [
    'NumberofBuildings',
    'YearsENERGYSTARCertified',
]

sea_2019 = pd.read_csv(path_19)
sea_2019 = drop_columns(sea_2019, columns_to_drop_19)
sea_2019 = convert(sea_2019, convert_to_float_19, convert_to_int_19)
sea_2019 = rename(sea_2019, columns_to_rename_19)
sea_2019[[columns_to_add_19]] = None # adding missing columns with no data inside
sea_2019 = sort_columns(sea_2019, columns_order)

sea_2019.to_csv('data/clean/2019-building-energy-benchmarking-clean.csv', index=False)

# %% [markdown]
# # 2020

# %%
# fixed order of columns for all data is saved in columns_order.py

path_20 = 'data/raw/2020_Building_Energy_Benchmarking.csv'

columns_to_drop_20 = [
    'TaxParcelIdentificationNumber',
    'City', 
    'State', 
    'PropertyGFABuilding(s)', 
    'LargestPropertyUseType', 
    'LargestPropertyUseTypeGFA', 
    'SecondLargestPropertyUseType',
    'SecondLargestPropertyUseTypeGFA', 
    'ThirdLargestPropertyUseType',
    'ThirdLargestPropertyUseTypeGFA', 
    'EPAPropertyType',
    'ComplianceIssue',
    'ComplianceStatus'
]

convert_to_float_20 = [
    'Latitude', 
    'Longitude',
    'ZipCode'
]

convert_to_int_20 = [
    'SiteEnergyUse(kBtu)',
    'SiteEnergyUseWN(kBtu)',
    'Electricity(kBtu)',
    'NaturalGas(kBtu)'
]

columns_to_rename_20 = {
    'BuildingName': 'PropertyName',
    'TotalGHGEmissions': 'GHGEmissions(MetricTonsCO2e)',
    'GHGEmissionsIntensity': 'GHGEmissionsIntensity(kgCO2e/ft2)'
}

columns_to_add_20 = [
    'YearsENERGYSTARCertified',
    'PrimaryPropertyType'
]

sea_2020 = pd.read_csv(path_20)
sea_2020 = drop_columns(sea_2020, columns_to_drop_20)
sea_2020 = convert(sea_2020, convert_to_float_20, convert_to_int_20)
sea_2020 = rename(sea_2020, columns_to_rename_20)
sea_2020[[columns_to_add_20]] = None # adding missing columns with no data inside
sea_2020 = sort_columns(sea_2020, columns_order)

sea_2020.to_csv('data/clean/2020-building-energy-benchmarking-clean.csv', index=False)

# %% [markdown]
# # 2. Concatenating data

# %%
lista = ['a', 'b', 'c']

for index, element in enumerate(lista):
    print(index, element)
# Out:
# 0 a
# 1 b
# 2 c

# %%
import pandas as pd
from os import listdir
from os.path import isfile, join

data_path = 'data\clean'
# taking full path of all files 
files_full_path = [join(data_path, f) for f in listdir(data_path) if isfile(join(data_path, f))]
files_full_path
# Out:
# ['data\\clean\\2015-building-energy-benchmarking-clean.csv',
#  'data\\clean\\2016-building-energy-benchmarking-clean.csv',
#  'data\\clean\\2017-building-energy-benchmarking-clean (1).csv',
#  'data\\clean\\2019-building-energy-benchmarking-clean.csv',
#  'data\\clean\\2020-building-energy-benchmarking-clean.csv']

# %%
data_list = []

for file in files_full_path:
    df = pd.read_csv(file)
    data_list.append(df)

sea_all = pd.concat(data_list, axis=0, ignore_index=True)

# %%
sea_all.to_csv(r'data\ALL_YEARS_building-energy-benchmarking-clean.csv')

# %%
pd.set_option('display.max_columns', None)
sea_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17009 entries, 0 to 17008
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   OSEBuildingID                      17009 non-null  int64
#  1   DataYear                           17009 non-null  int64
#  2   BuildingType                       17009 non-null  object
#  3   PrimaryPropertyType                13517 non-null  object
#  4   PropertyName                       17009 non-null  object
#  5   Address                            17009 non-null  object
#  6   ZipCode                            16893 non-null  float64
#  7   CouncilDistrictCode                16966 non-null  float64
#  8   Neighborhood                       16988 non-null  object
#  9   Latitude                           16988 non-null  float64
#  10  Longitude                          16988 non-null  float64
#  11  YearBuilt                          17009 non-null  int64
#  12  NumberofFloors                     17001 non-null  float64
#  13  NumberofBuildings                  13595 non-null  float64
#  14  PropertyGFATotal                   17009 non-null  int64
#  15  PropertyGFAParking                 17009 non-null  int64
#  16  YearsENERGYSTARCertified           3652 non-null   object
#  17  ENERGYSTARScore                    12693 non-null  float64
#  18  SiteEUI(kBtu/sf)                   17009 non-null  float64
#  19  SiteEUIWN(kBtu/sf)                 17009 non-null  float64
#  20  SourceEUI(kBtu/sf)                 17009 non-null  float64
#  21  SourceEUIWN(kBtu/sf)               17009 non-null  float64
#  22  SiteEnergyUse(kBtu)                17009 non-null  int64
#  23  SiteEnergyUseWN(kBtu)              17009 non-null  int64
#  24  SteamUse(kBtu)                     17009 non-null  float64
#  25  Electricity(kBtu)                  17009 non-null  int64
#  26  Electricity(kWh)                   17009 non-null  float64
#  27  NaturalGas(therms)                 17009 non-null  float64
#  28  NaturalGas(kBtu)                   17009 non-null  int64
#  29  GHGEmissions(MetricTonsCO2e)       17005 non-null  float64
#  30  GHGEmissionsIntensity(kgCO2e/ft2)  17005 non-null  float64
# dtypes: float64(16), int64(9), object(6)
# memory usage: 4.0+ MB

# %%
# sea_all['YearsENERGYSTARCertified'] = sea_all['YearsENERGYSTARCertified'].astype(float)
sea_all['YearsENERGYSTARCertified'].unique()
# Out:
# array([nan, '2016', '2014', '2012', '2015',
#        '2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008',
#        '2010, 2009, 2007', '2010, 2007', '2016, 2015', '2017, 2015',
#        '2015, 2014, 2012, 2011, 2009', '2012, 2009, 2008',
#        '2016, 2015, 2014, 2013, 2011, 2010, 2009, 2007, 2000',
#        '2016, 2009, 2008', '2016, 2014, 2012',
#        '2016, 2015, 2014, 2012, 2008',
#        '2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004',
#        '2014, 2013, 2011, 2010, 2009, 2008, 2007',
#        '2016, 2015, 2014, 2013, 2011, 2008',
#        '2016, 2015, 2014, 2013, 2008', '2016, 2015, 2013, 2012, 2010',
#        '2015, 2013, 2012, 2010', '2007', '2010', '2016, 2015, 2009, 2008',
#        '2013, 2009, 2008', '2017', '2017, 2011, 2010, 2007',
#        '2017, 2016, 2014, 2013, 2012, 2011, 2010, 2009, 2007',
#        '2015, 2014, 2012, 2010, 2008', '2012, 2010, 2009, 2008',
#        '2009, 2005', '2017, 2015, 2014, 2013', '2016, 2015, 2012',
#        '2012, 2010, 2007, 2006', '2011, 2009', '2009',
#        '2016, 2015, 2014, 2013, 2009, 2008',
#        '2016, 2015, 2014, 2013, 2011, 2009', '2017, 2016, 2012',
#        '2010, 2008', '2016, 2014, 2012, 2011, 2008, 2007', '2011',
#        '2015, 2014, 2013, 2011, 2009, 2008',
#        '2016, 2015, 2014, 2013, 2012, 2010, 2009', '2012, 2010',
#        '2016, 2011, 2010, 2009', '2016, 2015, 2012, 2009', '2016, 2012',
#        '2016, 2013, 2012, 2011, 2010, 2009, 2008',
#        '2016, 2015, 2013, 2012, 2011, 2010, 2009, 2008',
#        '2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2003, 2002, 2000',
#        '2016, 2015, 2012, 2009, 2007, 2006',
#        '2017, 2015, 2014, 2013, 2011', '2015, 2014', '2013', '2015, 2012',
#        '2016, 2015, 2014', '2017, 2016',
#        '2016, 2015, 2014, 2013, 2012, 2010, 2009, 2008',
#        '2016, 2015, 2010, 2009, 2008', '20172015',
#        '2017201620152014201320122011201020092008', '201020092007',
#        '201720102007', '20162015', '20152014201220112009', '201220092008',
#        '201620152014201320112010200920072000', '201620092008',
#        '201620142012', '20162015201420122008',
#        '2016201520142013201220112010200920082007200620052004',
#        '201520142013', '2014201320112010200920082007', '2016201520142013',
#        '2017201620152014201320112008', '201720162015201420132008',
#        '20162015201320122010', '2015201320122010', '20162011201020092008',
#        '20172016201520092008', '2017201320092008', '2017201120102007',
#        '201720162014201320122011201020092007', '201720152014201220102008',
#        '20092005', '2017201520142013', '201620152012', '2012201020072006',
#        '20112009', '201620152014201320092008', '201620152014201320112009',
#        '2016201520142013201220112010', '201720162012', '20102008',
#        '201620142012201120082007', '2017201520142013201120092008',
#        '2016201520142013201220102009', '2016201120102009',
#        '2016201520122009', '20162012', '2016201320122011201020092008',
#        '2017201620152012200920072006', '20162015201320122011201020092008',
#        '2014201320122008',
#        '201620152014201320122011201020092008200720062005200320022000',
#        '2014201020082001', '20172015201420132011', '20172016', '20152014',
#        '20152012', '201620152014', '201720162015',
#        '20162015201420132012201020092008', '20162015201020092008', 0.0,
#        2016.0, 201820172016.0, 2014.0, 2.0182017201620157e+23, 20182012.0,
#        20172015.0, 2.0172016201520142e+39, 201020092007.0,
#        2018201720102007.2, 2018201720162015.2, 20182017.0,
#        2.018201520142012e+23, 201220092008.0, 2018.0, 20162015.0,
#        2018201620092008.0, 2018201620142012.0, 2.0182017201620152e+27,
#        2.0182017201620158e+59, 2018201520142012.8, 2.017201420132011e+31,
#        2.017201620152014e+19, 2.0182017201620152e+31, 2018201720152010.0,
#        2015201320122010.0, 2.016201120102009e+19, 2007.0, 2010.0,
#        2017201320092008.0, 2015.0, 2017.0, 2017201120102007.2, 20092005.0,
#        2.0182017201620138e+39, 2.0182017201520143e+27,
#        2.018201720152014e+19, 2.0182017201620152e+19, 2012201020072006.0,
#        20112009.0, 2009.0, 2.017201620152014e+31, 2018201720162012.0,
#        201820172008.0, 20102008.0, 2.017201620142012e+27,
#        2.017201520142013e+27, 2.018201720162015e+35, 2016201120102008.8,
#        2016201520122008.8, 20182009.0, 2.0182017201620153e+39,
#        2014201320122008.0, 2.0182017201620152e+67, 2014201020082000.8,
#        2018201720162007.2, 2011.0, 2.018201720152014e+23, 20172016.0,
#        2013.0, 201720152014.0, 20152012.0, 201720162015.0, 20182016.0,
#        201620152014.0, 20182013.0, 20172013.0, 2017201620152014.0,
#        201820152014.0, 2017201620092008.0, 20172014.0], dtype=object)

# %%
sea_all['YearsENERGYSTARCertified'] = sea_all['YearsENERGYSTARCertified'].apply(lambda x: '{:.0f}'.format(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_644/3817222028.py in <module>
# ----> 1 sea_all['YearsENERGYSTARCertified'] = sea_all['YearsENERGYSTARCertified'].apply(lambda x: '{:.0f}'.format(x))
#
# e:\python\projects\seattle\venv\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# e:\python\projects\seattle\venv\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# e:\python\projects\seattle\venv\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1097                 # "Callable[[Any], Any]"
# -> 1098                 mapped = lib.map_infer(
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
#
# e:\python\projects\seattle\venv\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp/ipykernel_644/3817222028.py in <lambda>(x)
# ----> 1 sea_all['YearsENERGYSTARCertified'] = sea_all['YearsENERGYSTARCertified'].apply(lambda x: '{:.0f}'.format(x))
#
# ValueError: Unknown format code 'f' for object of type 'str'

# %%
sea_all['YearsENERGYSTARCertified'].unique()
# Out:
# array(['0                                                      nan\n1                                                      nan\n2                                                      nan\n3                                                      nan\n4                                                      nan\n5                                                      nan\n6                                                      nan\n7                                                      nan\n8                                                      nan\n9                                                      nan\n10                                                     nan\n11                                                     nan\n12                                                     nan\n13                                                     nan\n14                                                     nan\n15                                                     nan\n16                                                     nan\n17                                                     nan\n18                                                     nan\n19                                                     nan\n20                                                     nan\n21                                                     nan\n22                                                     nan\n23                                                     nan\n24                                                     nan\n25                                                     nan\n26                                                     nan\n27                                                     nan\n28                                                     nan\n29                                                     nan\n30                                                     nan\n31                                                     nan\n32                                                     nan\n33                                                     nan\n34                                                     nan\n35                                                     nan\n36                                                    2016\n37                                                     nan\n38                                                     nan\n39                                                     nan\n40                                                     nan\n41                                                     nan\n42                                                     nan\n43                                                    2016\n44                                                     nan\n45                                                     nan\n46                                                     nan\n47                                                     nan\n48                                                     nan\n49                                                     nan\n50                                                     nan\n51                                                     nan\n52                                                    2014\n53                                                     nan\n54                                                     nan\n55                                                     nan\n56                                                     nan\n57                                                     nan\n58                                                     nan\n59                                                     nan\n60                                                     nan\n61                                                     nan\n62                                                     nan\n63                                                     nan\n64                                                     nan\n65                                                     nan\n66                               ...
#       dtype=object)

# %%
sea_all[sea_all['YearsENERGYSTARCertified'] =='2.0182017201520143e+27']
# Out:
#       OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 6957            406      2017  NonResidential        Large Office
#
#         PropertyName          Address  ZipCode  CouncilDistrictCode  \
# 6957  520 Pike Tower  520 Pike Street  98101.0                  7.0
#
#      Neighborhood  Latitude  Longitude  YearBuilt  NumberofFloors  \
# 6957     DOWNTOWN  47.61125 -122.33494       1983            29.0
#
#       NumberofBuildings  PropertyGFATotal  PropertyGFAParking  \
# 6957                1.0            500000                   0
#
#      YearsENERGYSTARCertified  ENERGYSTARScore  SiteEUI(kBtu/sf)  \
# 6957   2.0182017201520143e+27             92.0              47.1
#
#       SiteEUIWN(kBtu/sf)  SourceEUI(kBtu/sf)  SourceEUIWN(kBtu/sf)  \
# 6957                45.9               147.9                 144.2
#
#       SiteEnergyUse(kBtu)  SiteEnergyUseWN(kBtu)  SteamUse(kBtu)  \
# 6957             20055690               19554536             0.0
#
#       Electricity(kBtu)  Electricity(kWh)  NaturalGas(therms)  \
# 6957           20055686         5877985.0                 0.0
#
#       NaturalGas(kBtu)  GHGEmissions(MetricTonsCO2e)  \
# 6957                 0                         82.97
#
#       GHGEmissionsIntensity(kgCO2e/ft2)
# 6957                              0.166

# %%
sea_17 = pd.read_csv('data/clean/2017-building-energy-benchmarking-clean (1).csv')

# %%
sea_17 = pd.read_csv('data/clean/2017-building-energy-benchmarking-clean (1).csv')
sea_17['YearsENERGYSTARCertified'] = sea_17['YearsENERGYSTARCertified'].astype(float)
sea_17['YearsENERGYSTARCertified'].unique()
# Out:
# array([0.00000000e+00, 2.01600000e+03, 2.01820172e+11, 2.01400000e+03,
#        2.01820172e+23, 2.01820120e+07, 2.01720150e+07, 2.01720162e+39,
#        2.01020092e+11, 2.01820172e+15, 2.01820172e+15, 2.01820170e+07,
#        2.01820152e+23, 2.01220092e+11, 2.01800000e+03, 2.01620150e+07,
#        2.01820162e+15, 2.01820162e+15, 2.01820172e+27, 2.01820172e+59,
#        2.01820152e+15, 2.01720142e+31, 2.01720162e+19, 2.01820172e+31,
#        2.01820172e+15, 2.01520132e+15, 2.01620112e+19, 2.00700000e+03,
#        2.01000000e+03, 2.01720132e+15, 2.01500000e+03, 2.01700000e+03,
#        2.01720112e+15, 2.00920050e+07, 2.01820172e+39, 2.01820172e+27,
#        2.01820172e+19, 2.01820172e+19, 2.01220102e+15, 2.01120090e+07,
#        2.00900000e+03, 2.01720162e+31, 2.01820172e+15, 2.01820172e+11,
#        2.01020080e+07, 2.01720162e+27, 2.01720152e+27, 2.01820172e+35,
#        2.01620112e+15, 2.01620152e+15, 2.01820090e+07, 2.01820172e+39,
#        2.01420132e+15, 2.01820172e+67, 2.01420102e+15, 2.01820172e+15,
#        2.01100000e+03, 2.01820172e+23, 2.01720160e+07, 2.01300000e+03,
#        2.01720152e+11, 2.01520120e+07, 2.01720162e+11, 2.01820160e+07,
#        2.01620152e+11, 2.01820130e+07, 2.01720130e+07, 2.01720162e+15,
#        2.01820152e+11, 2.01720162e+15, 2.01720140e+07])

# %%
sea_17.YearsENERGYSTARCertified = sea_17.YearsENERGYSTARCertified.apply(lambda x: '{:.0f}'.format(x))
sea_17['YearsENERGYSTARCertified'].unique()
# Out:
# array(['0', '2016', '201820172016', '2014', '201820172016201567830016',
#        '20182012', '20172015', '2017201620152014247476696188383372771328',
#        '201020092007', '2018201720102007', '2018201720162015', '20182017',
#        '201820152014201212108800', '201220092008', '2018', '20162015',
#        '2018201620092008', '2018201620142012',
#        '2018201720162015161293471744',
#        '201820172016201575150213072976220650461987661951224070012928',
#        '2018201520142013', '20172014201320110965854327275520',
#        '20172016201520140288', '20182017201620151634924949995520',
#        '2018201720152010', '2015201320122010', '20162011201020088320',
#        '2007', '2010', '2017201320092008', '2015', '2017',
#        '2017201120102007', '20092005',
#        '2018201720162013837526119462501844254720',
#        '2018201720152014278405128192', '20182017201520140288',
#        '20182017201620152320', '2012201020072006', '20112009', '2009',
#        '20172016201520139018561933803520', '2018201720162012',
#        '201820172008', '20102008', '2017201620142012137159524352',
#        '2017201520142012881850859520',
#        '201820172016201505648696785322901504', '2016201120102009',
#        '2016201520122009', '20182009',
#        '2018201720162015348683393980788312637440', '2014201320122008',
#        '20182017201620152296786801115341433995184402420411865125240965169152',
#        '2014201020082001', '2018201720162007', '2011',
#        '201820172015201410875392', '20172016', '2013', '201720152014',
#        '20152012', '201720162015', '20182016', '201620152014', '20182013',
#        '20172013', '2017201620152014', '201820152014', '2017201620092008',
#        '20172014'], dtype=object)

# %%
sea_17[sea_17['YearsENERGYSTARCertified'] == 20092005]
# Out:
#      OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 271            422      2017  NonResidential        Large Office
# 289            423      2017  NonResidential        Large Office
#
#          PropertyName                Address  ZipCode  CouncilDistrictCode  \
# 271  Two Union Square          601 Union St.  98101.0                  7.0
# 289  One Union Square  600 University Street  98101.0                  7.0
#
#     Neighborhood  Latitude  Longitude  YearBuilt  NumberofFloors  \
# 271     DOWNTOWN  47.61043 -122.33206       1989              56
# 289     DOWNTOWN  47.60967 -122.33229       1980              36
#
#      NumberofBuildings  PropertyGFATotal  PropertyGFAParking  \
# 271                1.0           1735079              389860
# 289                1.0            794592               36606
#
#      YearsENERGYSTARCertified  ENERGYSTARScore  SiteEUI(kBtu/sf)  \
# 271                  20092005             98.0              34.9
# 289                  20092005             97.0              34.5
#
#      SiteEUIWN(kBtu/sf)  SourceEUI(kBtu/sf)  SourceEUIWN(kBtu/sf)  \
# 271                34.4               107.3                 106.0
# 289                33.9               106.3                 104.4
#
#      SiteEnergyUse(kBtu)  SiteEnergyUseWN(kBtu)  SteamUse(kBtu)  \
# 271             46991252               46332688         1471912
# 289             26138674               25681880               0
#
#      Electricity(kBtu)  Electricity(kWh)  NaturalGas(therms)  \
# 271           45336629          13287406                1827
# 289           25431089           7453426                7075
#
#      NaturalGas(kBtu)  GHGEmissions(MetricTonsCO2e)  \
# 271            182705                        275.51
# 289            707582                        142.79
#
#      GHGEmissionsIntensity(kgCO2e/ft2)
# 271                              0.159
# 289                              0.180

# %%
sea_17[sea_17['OSEBuildingID'] == 423]
# Out:
#      OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 289            423      2017  NonResidential        Large Office
#
#          PropertyName                Address  ZipCode  CouncilDistrictCode  \
# 289  One Union Square  600 University Street  98101.0                  7.0
#
#     Neighborhood  Latitude  Longitude  YearBuilt  NumberofFloors  \
# 289     DOWNTOWN  47.60967 -122.33229       1980              36
#
#      NumberofBuildings  PropertyGFATotal  PropertyGFAParking  \
# 289                1.0            794592               36606
#
#      YearsENERGYSTARCertified  ENERGYSTARScore  SiteEUI(kBtu/sf)  \
# 289                20092005.0             97.0              34.5
#
#      SiteEUIWN(kBtu/sf)  SourceEUI(kBtu/sf)  SourceEUIWN(kBtu/sf)  \
# 289                33.9               106.3                 104.4
#
#      SiteEnergyUse(kBtu)  SiteEnergyUseWN(kBtu)  SteamUse(kBtu)  \
# 289             26138674               25681880               0
#
#      Electricity(kBtu)  Electricity(kWh)  NaturalGas(therms)  \
# 289           25431089           7453426                7075
#
#      NaturalGas(kBtu)  GHGEmissions(MetricTonsCO2e)  \
# 289            707582                        142.79
#
#      GHGEmissionsIntensity(kgCO2e/ft2)
# 289                               0.18

# %%
sea_17[sea_17['YearsENERGYSTARCertified'] == -2147483648]
# Out:
#       OSEBuildingID  DataYear          BuildingType   PrimaryPropertyType  \
# 43               57      2017        NonResidential          Large Office
# 66              100      2017        NonResidential          Large Office
# 71              107      2017        NonResidential          Large Office
# 203             329      2017        NonResidential          Large Office
# 205             331      2017        NonResidential          Large Office
# ...             ...       ...                   ...                   ...
# 3187          49776      2017        NonResidential          Large Office
# 3219          49857      2017  Multifamily MR (5-9)  Mid-Rise Multifamily
# 3281          49985      2017        NonResidential          Large Office
# 3305          50016      2017  Multifamily MR (5-9)  Mid-Rise Multifamily
# 3330          50046      2017  Multifamily MR (5-9)  Mid-Rise Multifamily
#
#                  PropertyName               Address  ZipCode  \
# 43               5th and Pine       413 Pine Street  98101.0
# 66      City Place III - SEDO  551 Boren Ave. North  98109.0
# 71       City Place IV - SEDO     333 Boren Ave. N.  98109.0
# 203          1700 Seventh Ave          1700 Seventh  98101.0
# 205        The Tower Building          1809 7th Ave  98101.0
# ...                       ...                   ...      ...
# 3187       Market Place Tower       2025 1st Avenue  98121.0
# 3219  AMLI South Lake Union 1   1260 Republican St.  98109.0
# 3281          Amazon Phase VI  500 9th Avenue North  98109.0
# 3305              AMLI Mark24     2428 NW Market St  98107.0
# 3330  AMLI South Lake Union 2     528 Pontius Ave N  98109.0
#
#       CouncilDistrictCode Neighborhood  Latitude  Longitude  YearBuilt  \
# 43                    7.0     DOWNTOWN  47.61130 -122.33659       1973
# 66                    7.0   LAKE UNION  47.62424 -122.33646       2010
# 71                    7.0   LAKE UNION  47.62112 -122.33629       2010
# 203                   7.0     DOWNTOWN  47.61399 -122.33523       2000
# 205                   7.0     DOWNTOWN  47.61375 -122.33566       1930
# ...                   ...          ...       ...        ...        ...
# 3187                  7.0     DOWNTOWN  47.61156 -122.34401       1988
# 3219                  7.0   LAKE UNION  47.62336 -122.33085       2013
# 3281                  7.0   LAKE UNION  47.62384 -122.33941       2014
# 3305                  6.0      BALLARD  47.66895 -122.38881       2014
# 3330                  7.0   LAKE UNION  47.62383 -122.33143       2014
#
#       NumberofFloors  NumberofBuildings  PropertyGFATotal  PropertyGFAParking  \
# 43                 5                1.0            168115                   0
# 66                 5                1.0            316306                   0
# 71                12                1.0            571329                   0
# 203               23                1.0            747747              205076
# 205               17                1.0            204790               30000
# ...              ...                ...               ...                 ...
# 3187              13                1.0            354086              149326
# 3219               7                1.0            229742                   0
# 3281               6                1.0            596376              169195
# 3305               7                1.0            418285                   0
# 3330               8                1.0            110964                   0
#
#       YearsENERGYSTARCertified  ENERGYSTARScore  SiteEUI(kBtu/sf)  \
# 43                 -2147483648             85.0              56.4
# 66                 -2147483648             95.0              57.0
# 71                 -2147483648             92.0              62.5
# 203                -2147483648             92.0              54.8
# 205                -2147483648             91.0              48.1
# ...                        ...              ...               ...
# 3187               -2147483648             91.0              55.6
# 3219               -2147483648             99.0              31.5
# 3281               -2147483648             99.0              41.4
# 3305               -2147483648            100.0              20.4
# 3330               -2147483648             97.0              32.8
#
#       SiteEUIWN(kBtu/sf)  SourceEUI(kBtu/sf)  SourceEUIWN(kBtu/sf)  \
# 43                  55.5               177.2                 174.1
# 66                  57.0               155.9                 155.9
# 71                  61.8               172.1                 169.9
# 203                 54.4               161.0                 159.8
# 205                 46.8               129.5                 128.1
# ...                  ...                 ...                   ...
# 3187                54.0               158.9                 155.0
# 3219                31.2                73.8                  73.5
# 3281                40.6               117.0                 114.6
# 3305                20.1                51.7                  50.8
# 3330                31.7                81.7                  78.3
#
#       SiteEnergyUse(kBtu)  SiteEnergyUseWN(kBtu)  SteamUse(kBtu)  \
# 43                9567585                9402433               0
# 66               16381541               16384160               0
# 71               39074696               38648836               0
# 203              30229138               30027230               0
# 205               8360560                8138434               0
# ...                   ...                    ...             ...
# 3187             13046611               12668063               0
# 3219              5567889                5521985               0
# 3281             17705612               17342080               0
# 3305              8523793                8410720               0
# 3330              3424986                3311554               0
#
#       Electricity(kBtu)  Electricity(kWh)  NaturalGas(therms)  \
# 43              9567584           2804098                   0
# 66             13206806           3870693               31747
# 71             31822031           9326504               72526
# 203            27310446           8004234               29186
# 205             6566011           1924388               17945
# ...                 ...               ...                 ...
# 3187           11286552           3307899               17600
# 3219            3442771           1009018               21251
# 3281           15028529           4404610               26770
# 3305            6061019           1776383               24627
# 3330            2359853            691633               10651
#
#       NaturalGas(kBtu)  GHGEmissions(MetricTonsCO2e)  \
# 43                   0                         39.58
# 66             3174733                        223.25
# 71             7252659                        516.84
# 203            2918686                        268.00
# 205            1794547                        122.47
# ...                ...                           ...
# 3187           1760057                        140.17
# 3219           2125118                        127.11
# 3281           2677080                        204.35
# 3305           2462773                        155.87
# 3330           1065132                         66.33
#
#       GHGEmissionsIntensity(kgCO2e/ft2)
# 43                                0.235
# 66                                0.706
# 71                                0.905
# 203                               0.358
# 205                               0.598
# ...                                 ...
# 3187                              0.396
# 3219                              0.553
# 3281                              0.343
# 3305                              0.373
# 3330                              0.598
#
# [71 rows x 31 columns]

# %%
sea_17 = pd.read_csv('data/clean/2017-building-energy-benchmarking-clean (1).csv')
value = sea_17['YearsENERGYSTARCertified'][sea_17['OSEBuildingID'] == 57]
value
# Out:
# 43    2.018202e+11
# Name: YearsENERGYSTARCertified, dtype: float64

# %%
int(value.values[0])
# Out:
# 201820172016

# %%
value.astype(int)
# Out:
# 43   -2147483648
# Name: YearsENERGYSTARCertified, dtype: int32
